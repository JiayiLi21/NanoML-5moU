# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import pandas as pd
import numpy as np
#from xgboost import XGBClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import cross_validate
from sklearn import metrics
from sklearn.metrics import accuracy_score, confusion_matrix, roc_curve, roc_auc_score
import joblib
import os
import csv
import re
import warnings
warnings.filterwarnings('ignore')
import matplotlib.pyplot as plt

# %%
dataset=pd.read_csv('/home/jiayi/5moU/data/DL_fromTombo/all_AGTTC.csv')
dataset
# Out:
#       indx   kmer    mean_1    mean_2    mean_3    mean_4    mean_5     std_1  \
# 0      260  AGTTC  0.513199  0.397293 -0.850444 -0.837177 -0.786233  0.047088
# 1      259  AGTTC  0.589209  0.568374 -0.717482 -0.762448 -0.789418  0.062266
# 2      243  AGTTC  0.458838  0.109656 -0.797939 -0.820008 -0.756034  0.149853
# 3      260  AGTTC  0.457595  0.472804 -0.688376 -0.681815 -0.679743  0.060894
# 4      260  AGTTC  0.528384  0.423719 -0.713185 -0.825872 -0.800544  0.029393
# ...    ...    ...       ...       ...       ...       ...       ...       ...
# 2628   260  AGTTC  0.787659  0.405793 -0.611869 -0.739305 -0.605124  0.169036
# 2629   161  AGTTC  0.396310  0.499622 -0.619268 -0.546544 -0.762006  0.090910
# 2630   240  AGTTC  0.589990  0.614284 -0.632994 -0.789089 -0.753708  0.172348
# 2631   260  AGTTC  0.661435  0.551367 -0.694797 -0.734620 -0.571503  0.110638
# 2632    33  AGTTC  0.695724  0.689144 -0.430299 -0.333123 -0.287625  0.108741
#
# ...

# %%
AGTTC_0=pd.DataFrame()
AGTTC_0['indx']=dataset['indx']
AGTTC_0['kmer']=dataset['kmer']
AGTTC_0['mean_0']=dataset['mean_3']
AGTTC_0['std_0']=dataset['std_3']
AGTTC_0['mdintense_0']=dataset['mdintense_3']
AGTTC_0['length2']=dataset['L-3']
AGTTC_0['label']=dataset['label']
AGTTC_0
# Out:
#       indx   kmer    mean_0     std_0  mdintense_0  length2  label
# 0      260  AGTTC -0.850444  0.031234    -0.846254        6      1
# 1      259  AGTTC -0.717482  0.038712    -0.727349        6      1
# 2      243  AGTTC -0.797939  0.034345    -0.796560        6      1
# 3      260  AGTTC -0.688376  0.025067    -0.686393        6      1
# 4      260  AGTTC -0.713185  0.162593    -0.768558        6      1
# ...    ...    ...       ...       ...          ...      ...    ...
# 2628   260  AGTTC -0.611869  0.138040    -0.667700        6      0
# 2629   161  AGTTC -0.619268  0.130815    -0.642935        6      0
# 2630   240  AGTTC -0.632994  0.188418    -0.685807        6      0
# 2631   260  AGTTC -0.694797  0.049018    -0.676666        6      0
# 2632    33  AGTTC -0.430299  0.050444    -0.444039        6      0
#
# [2633 rows x 7 columns]

# %%
AGTTC_0.to_csv('/home/jiayi/5moU/data/DL_fromTombo/AGTTC_0.csv',index=False)

# %%
AGTTC_01=pd.DataFrame()
AGTTC_01['indx']=dataset['indx']
AGTTC_01['kmer']=dataset['kmer']
AGTTC_01['mean_2']=dataset['mean_2']
AGTTC_01['mean_3']=dataset['mean_3']
AGTTC_01['mean_4']=dataset['mean_4']

AGTTC_01['std_2']=dataset['std_2']
AGTTC_01['std_3']=dataset['std_3']
AGTTC_01['std_4']=dataset['std_4']


AGTTC_01['mdintense_2']=dataset['mdintense_2']
AGTTC_01['mdintense_3']=dataset['mdintense_3']
AGTTC_01['mdintense_4']=dataset['mdintense_4']

AGTTC_01['length2_2']=dataset['L-2']
AGTTC_01['length2_3']=dataset['L-3']
AGTTC_01['length2_4']=dataset['L-4']
AGTTC_01['label']=dataset['label']
AGTTC_01
# Out:
#       indx   kmer    mean_2    mean_3    mean_4     std_2     std_3     std_4  \
# 0      260  AGTTC  0.397293 -0.850444 -0.837177  0.272815  0.031234  0.029964
# 1      259  AGTTC  0.568374 -0.717482 -0.762448  0.080098  0.038712  0.037672
# 2      243  AGTTC  0.109656 -0.797939 -0.820008  0.419986  0.034345  0.031689
# 3      260  AGTTC  0.472804 -0.688376 -0.681815  0.174125  0.025067  0.042501
# 4      260  AGTTC  0.423719 -0.713185 -0.825872  0.277885  0.162593  0.018993
# ...    ...    ...       ...       ...       ...       ...       ...       ...
# 2628   260  AGTTC  0.405793 -0.611869 -0.739305  0.279195  0.138040  0.044008
# 2629   161  AGTTC  0.499622 -0.619268 -0.546544  0.031997  0.130815  0.250404
# 2630   240  AGTTC  0.614284 -0.632994 -0.789089  0.280588  0.188418  0.045102
# 2631   260  AGTTC  0.551367 -0.694797 -0.734620  0.231089  0.049018  0.025361
# 2632    33  AGTTC  0.689144 -0.430299 -0.333123  0.156471  0.050444  0.041834
#
# ...

# %%
AGTTC_01.to_csv('/home/jiayi/5moU/data/DL_fromTombo/AGTTC_01.csv',index=False)
