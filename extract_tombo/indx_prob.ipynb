# %%
import pandas as pd

# %%
all_xgb_pred=pd.read_csv('/home/jiayi/5moU/data/DL_fromTombo/all_xgb_pred.csv')
all_xgb_pred
# Out:
#          indx   kmer    mean_1    mean_2    mean_3    mean_4    mean_5  \
# 0          20  CATCT -0.261382 -0.290529 -0.375176 -0.548695 -0.420694
# 1          22  TCTTC -0.375176 -0.548695 -0.420694 -0.102165  0.324141
# 2          23  CTTCG -0.548695 -0.420694 -0.102165  0.324141  0.612248
# 3          35  CGTGG -0.134270  0.017096  0.317245  0.286391  0.191036
# 4          44  CCTGC -1.068734 -0.164691  0.164829  0.237456 -0.655237
# ...       ...    ...       ...       ...       ...       ...       ...
# 1822819   350  GCTGG  0.160716  0.201952  0.291149  0.341133  0.261907
# 1822820   365  GATCC  0.713934  0.005522 -0.667390 -0.689873 -0.575091
# 1822821   374  GATCC  0.404221  0.204545 -0.725696 -0.713145  0.062983
# 1822822   377  CCTGA -0.713145  0.062983  0.264506  0.270585  0.073087
# 1822823   380  GATCA  0.270585  0.073087 -0.577806 -0.538803  0.255019
#
#             std_1     std_2     std_3  ...  mdintense_4  mdintense_5  L-1  \
# ...

# %%
sites=all_xgb_pred['indx']
prob=all_xgb_pred['prob']

# %%
Visual=all_xgb_pred[['indx','kmer','label']]
Visual
# Out:
#          indx   kmer  label
# 0          20  CATCT      1
# 1          22  TCTTC      1
# 2          23  CTTCG      1
# 3          35  CGTGG      1
# 4          44  CCTGC      1
# ...       ...    ...    ...
# 1822819   350  GCTGG      0
# 1822820   365  GATCC      0
# 1822821   374  GATCC      0
# 1822822   377  CCTGA      0
# 1822823   380  GATCA      0
#
# [1822824 rows x 3 columns]

# %%
Visual['XGB_prob']=all_xgb_pred['prob']
Visual
# Out:
# /tmp/ipykernel_677391/1845215218.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Visual['XGB_prob']=all_xgb_pred['prob']
#          indx   kmer  label  XGB_prob
# 0          20  CATCT      1  0.870557
# 1          22  TCTTC      1  0.955709
# 2          23  CTTCG      1  0.973307
# 3          35  CGTGG      1  0.161993
# 4          44  CCTGC      1  0.999986
# ...       ...    ...    ...       ...
# 1822819   350  GCTGG      0  0.044694
# 1822820   365  GATCC      0  0.015414
# 1822821   374  GATCC      0  0.000200
# 1822822   377  CCTGA      0  0.058123
# 1822823   380  GATCA      0  0.005027
#
# [1822824 rows x 4 columns]

# %%
all_RF_pred=pd.read_csv('/home/jiayi/5moU/data/DL_fromTombo/all_RF_pred.csv')
all_RF_pred
# Out:
#          indx   kmer    mean_1    mean_2    mean_3    mean_4    mean_5  \
# 0          20  CATCT -0.261382 -0.290529 -0.375176 -0.548695 -0.420694
# 1          22  TCTTC -0.375176 -0.548695 -0.420694 -0.102165  0.324141
# 2          23  CTTCG -0.548695 -0.420694 -0.102165  0.324141  0.612248
# 3          35  CGTGG -0.134270  0.017096  0.317245  0.286391  0.191036
# 4          44  CCTGC -1.068734 -0.164691  0.164829  0.237456 -0.655237
# ...       ...    ...       ...       ...       ...       ...       ...
# 1822819   350  GCTGG  0.160716  0.201952  0.291149  0.341133  0.261907
# 1822820   365  GATCC  0.713934  0.005522 -0.667390 -0.689873 -0.575091
# 1822821   374  GATCC  0.404221  0.204545 -0.725696 -0.713145  0.062983
# 1822822   377  CCTGA -0.713145  0.062983  0.264506  0.270585  0.073087
# 1822823   380  GATCA  0.270585  0.073087 -0.577806 -0.538803  0.255019
#
#             std_1     std_2     std_3  ...  mdintense_4  mdintense_5  L-1  \
# ...

# %%
Visual['RF_prob']=all_RF_pred['prob']
Visual
# Out:
# /tmp/ipykernel_677391/4117530125.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Visual['RF_prob']=all_RF_pred['prob']
#          indx   kmer  label  XGB_prob  RF_prob
# 0          20  CATCT      1  0.870557     0.83
# 1          22  TCTTC      1  0.955709     0.97
# 2          23  CTTCG      1  0.973307     0.93
# 3          35  CGTGG      1  0.161993     0.72
# 4          44  CCTGC      1  0.999986     1.00
# ...       ...    ...    ...       ...      ...
# 1822819   350  GCTGG      0  0.044694     0.05
# 1822820   365  GATCC      0  0.015414     0.10
# 1822821   374  GATCC      0  0.000200     0.05
# 1822822   377  CCTGA      0  0.058123     0.10
# 1822823   380  GATCA      0  0.005027     0.03
#
# [1822824 rows x 5 columns]

# %%
all_SVM_pred=pd.read_csv('/home/jiayi/5moU/data/DL_fromTombo/all_SVM_pred.csv')
all_SVM_pred
# Out:
#          indx   kmer    mean_1    mean_2    mean_3    mean_4    mean_5  \
# 0          20  CATCT -0.261382 -0.290529 -0.375176 -0.548695 -0.420694
# 1          22  TCTTC -0.375176 -0.548695 -0.420694 -0.102165  0.324141
# 2          23  CTTCG -0.548695 -0.420694 -0.102165  0.324141  0.612248
# 3          35  CGTGG -0.134270  0.017096  0.317245  0.286391  0.191036
# 4          44  CCTGC -1.068734 -0.164691  0.164829  0.237456 -0.655237
# ...       ...    ...       ...       ...       ...       ...       ...
# 1822819   350  GCTGG  0.160716  0.201952  0.291149  0.341133  0.261907
# 1822820   365  GATCC  0.713934  0.005522 -0.667390 -0.689873 -0.575091
# 1822821   374  GATCC  0.404221  0.204545 -0.725696 -0.713145  0.062983
# 1822822   377  CCTGA -0.713145  0.062983  0.264506  0.270585  0.073087
# 1822823   380  GATCA  0.270585  0.073087 -0.577806 -0.538803  0.255019
#
#             std_1     std_2     std_3  ...  mdintense_4  mdintense_5  L-1  \
# ...

# %%
Visual['SVM_prob']=all_SVM_pred['prob']
Visual
# Out:
# /tmp/ipykernel_677391/2304149042.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Visual['SVM_prob']=all_SVM_pred['prob']
#          indx   kmer  label  XGB_prob  RF_prob  SVM_prob
# 0          20  CATCT      1  0.870557     0.83  0.742585
# 1          22  TCTTC      1  0.955709     0.97  0.976235
# 2          23  CTTCG      1  0.973307     0.93  0.980302
# 3          35  CGTGG      1  0.161993     0.72  0.306606
# 4          44  CCTGC      1  0.999986     1.00  1.000000
# ...       ...    ...    ...       ...      ...       ...
# 1822819   350  GCTGG      0  0.044694     0.05  0.005096
# 1822820   365  GATCC      0  0.015414     0.10  0.043084
# 1822821   374  GATCC      0  0.000200     0.05  0.099116
# ...

# %%
# Out:
# 1822824

# %%
Mod=Visual[Visual['label']==1]
Mod
Mod.to_csv('/home/jiayi/5moU/data/DL_fromTombo/Mod_prob.csv',index=False)

# %%
Normal=Visual[Visual['label']==0]
Normal.to_csv('/home/jiayi/5moU/data/DL_fromTombo/Normal_prob.csv',index=False)

# %%
Mod['indx'].value_counts()
# Out:
# 41      458
# 206     448
# 38      425
# 260     418
# 95      416
#        ...
# 1560      1
# 1496      1
# 1462      1
# 1460      1
# 1580      1
# Name: indx, Length: 1602, dtype: int64

# %%
demo_mod_20=Mod[Mod['indx']==20]
demo_mod_20
# Out:
#         indx   kmer  label  XGB_prob  RF_prob  SVM_prob
# 0         20  CATCT      1  0.870557     0.83  0.742585
# 29        20  CCTGC      1  0.999907     1.00  1.000000
# 621       20  GATCA      1  0.667301     0.70  0.067551
# 702       20  AGTAC      1  0.997501     1.00  0.995541
# 2029      20  GCTGG      1  0.950208     0.91  0.965322
# ...      ...    ...    ...       ...      ...       ...
# 189332    20  TCTAC      1  0.997494     1.00  0.984278
# 189942    20  TCTAC      1  0.997645     0.93  0.572100
# 192150    20  GATCG      1  0.784588     0.74  0.089802
# 192471    20  GTTCT      1  0.999975     0.97  0.999997
# 195584    20  TCTAC      1  0.998743     0.93  0.995645
#
# [293 rows x 6 columns]

# %%
demo_normal_20=Normal[Normal['indx']==20]
demo_normal_20
# Out:
#          indx   kmer  label  XGB_prob  RF_prob  SVM_prob
# 197825     20  ACTGG      0  0.000023     0.00  0.005133
# 197977     20  CTTCA      0  0.000807     0.07  0.043721
# 198818     20  CCTGC      0  0.000012     0.00  0.003775
# 198844     20  TGTTC      0  0.000097     0.00  0.003735
# 198951     20  GATCA      0  0.000009     0.00  0.000119
# ...       ...    ...    ...       ...      ...       ...
# 1820199    20  TGTGC      0  0.001502     0.05  0.021288
# 1820282    20  CCTGA      0  0.001553     0.00  0.001379
# 1820316    20  CATGA      0  0.001904     0.00  0.062781
# 1820848    20  GATCC      0  0.000026     0.00  0.000063
# 1821663    20  GGTGC      0  0.002180     0.01  0.013676
#
# [2289 rows x 6 columns]

# %%
demo_False_20=demo_mod_20[demo_mod_20['XGB_prob']<=0.5]
demo_False_20
# Out:
#         indx   kmer  label  XGB_prob  RF_prob  SVM_prob
# 10505     20  GCTGG      1  0.352162     0.18  0.014373
# 21269     20  GATCG      1  0.034942     0.69  0.186787
# 39152     20  CATGA      1  0.026060     0.20  0.037343
# 41417     20  GGTGC      1  0.137078     0.63  0.021747
# 45473     20  CTTCA      1  0.385087     0.80  0.715329
# 51962     20  CGTGG      1  0.410887     0.62  0.003003
# 58171     20  CCTGA      1  0.420292     0.68  0.046438
# 69782     20  CCTGC      1  0.440465     0.72  0.050320
# 70193     20  GATCA      1  0.478457     0.80  0.189557
# 72499     20  GGTGG      1  0.369999     0.85  0.120984
# 75334     20  CGTGG      1  0.418677     0.81  0.151657
# 83942     20  CCTGC      1  0.410626     0.81  0.985818
# 86657     20  CCTGC      1  0.304472     0.28  0.114486
# 88002     20  CATCT      1  0.455192     0.67  0.031069
# 96263     20  AGTAC      1  0.125916     0.67  0.086637
# 96815     20  GATCA      1  0.324076     0.60  0.000008
# ...

# %%
AGTTC=Visual[Visual['kmer']=="AGTTC"]
AGTTC
# Out:
#          indx   kmer  label  XGB_prob  RF_prob  SVM_prob
# 80        260  AGTTC      1  0.999808     1.00  1.000000
# 1599      259  AGTTC      1  0.997499     0.90  0.999993
# 1829      243  AGTTC      1  0.983573     0.96  0.988261
# 2142      260  AGTTC      1  0.999894     0.98  1.000000
# 3070      260  AGTTC      1  0.999737     1.00  1.000000
# ...       ...    ...    ...       ...      ...       ...
# 1818323   260  AGTTC      0  0.000019     0.00  0.000301
# 1820621   161  AGTTC      0  0.011864     0.06  0.135134
# 1821325   240  AGTTC      0  0.000081     0.00  0.000390
# 1821871   260  AGTTC      0  0.000042     0.00  0.001392
# 1822332    33  AGTTC      0  0.000709     0.00  0.037365
#
# [2633 rows x 6 columns]

# %%
AGTTC['indx'].value_counts()
# Out:
# 260    1069
# 258     188
# 259     176
# 256      92
# 240      45
#        ...
# 127       1
# 185       1
# 212       1
# 173       1
# 45        1
# Name: indx, Length: 217, dtype: int64

# %%
mod_AGTTC=AGTTC[AGTTC['label']==1]
mod_AGTTC
# Out:
#         indx   kmer  label  XGB_prob  RF_prob  SVM_prob
# 80       260  AGTTC      1  0.999808     1.00  1.000000
# 1599     259  AGTTC      1  0.997499     0.90  0.999993
# 1829     243  AGTTC      1  0.983573     0.96  0.988261
# 2142     260  AGTTC      1  0.999894     0.98  1.000000
# 3070     260  AGTTC      1  0.999737     1.00  1.000000
# ...      ...    ...    ...       ...      ...       ...
# 194878   215  AGTTC      1  0.999713     0.99  0.993934
# 195266   216  AGTTC      1  0.999899     0.99  1.000000
# 195612   239  AGTTC      1  0.999376     0.97  0.999998
# 195838   260  AGTTC      1  0.999930     1.00  0.996089
# 196949   258  AGTTC      1  0.999851     0.96  1.000000
#
# [315 rows x 6 columns]

# %%
mod_AGTTC['indx'].value_counts()
# Out:
# 260    100
# 258     32
# 259     27
# 239     10
# 79      10
#       ...
# 234      1
# 18       1
# 61       1
# 27       1
# 191      1
# Name: indx, Length: 72, dtype: int64

# %%
mod_AGTTC.to_csv('/home/jiayi/5moU/data/DL_fromTombo/mod_AGTTC.csv')

# %%
Normal_AGTTC=AGTTC[AGTTC['label']==0]
Normal_AGTTC
Normal_AGTTC.to_csv('/home/jiayi/5moU/data/DL_fromTombo/normal_AGTTC.csv')

# %%
all_tombo=pd.read_csv('/home/jiayi/5moU/data/DL_fromTombo/all_tombo.csv')
all_tombo
# Out:
#          indx   kmer    mean_1    mean_2    mean_3    mean_4    mean_5  \
# 0          20  CATCT -0.261382 -0.290529 -0.375176 -0.548695 -0.420694
# 1          22  TCTTC -0.375176 -0.548695 -0.420694 -0.102165  0.324141
# 2          23  CTTCG -0.548695 -0.420694 -0.102165  0.324141  0.612248
# 3          35  CGTGG -0.134270  0.017096  0.317245  0.286391  0.191036
# 4          44  CCTGC -1.068734 -0.164691  0.164829  0.237456 -0.655237
# ...       ...    ...       ...       ...       ...       ...       ...
# 1822819   350  GCTGG  0.160716  0.201952  0.291149  0.341133  0.261907
# 1822820   365  GATCC  0.713934  0.005522 -0.667390 -0.689873 -0.575091
# 1822821   374  GATCC  0.404221  0.204545 -0.725696 -0.713145  0.062983
# 1822822   377  CCTGA -0.713145  0.062983  0.264506  0.270585  0.073087
# 1822823   380  GATCA  0.270585  0.073087 -0.577806 -0.538803  0.255019
#
#             std_1     std_2     std_3  ...  mdintense_2  mdintense_3  \
# ...

# %%
all_AGTTC=all_tombo[all_tombo['kmer']=="AGTTC"]
all_AGTTC
# Out:
#          indx   kmer    mean_1    mean_2    mean_3    mean_4    mean_5  \
# 80        260  AGTTC  0.513199  0.397293 -0.850444 -0.837177 -0.786233
# 1599      259  AGTTC  0.589209  0.568374 -0.717482 -0.762448 -0.789418
# 1829      243  AGTTC  0.458838  0.109656 -0.797939 -0.820008 -0.756034
# 2142      260  AGTTC  0.457595  0.472804 -0.688376 -0.681815 -0.679743
# 3070      260  AGTTC  0.528384  0.423719 -0.713185 -0.825872 -0.800544
# ...       ...    ...       ...       ...       ...       ...       ...
# 1818323   260  AGTTC  0.787659  0.405793 -0.611869 -0.739305 -0.605124
# 1820621   161  AGTTC  0.396310  0.499622 -0.619268 -0.546544 -0.762006
# 1821325   240  AGTTC  0.589990  0.614284 -0.632994 -0.789089 -0.753708
# 1821871   260  AGTTC  0.661435  0.551367 -0.694797 -0.734620 -0.571503
# 1822332    33  AGTTC  0.695724  0.689144 -0.430299 -0.333123 -0.287625
#
#             std_1     std_2     std_3  ...  mdintense_2  mdintense_3  \
# ...

# %%
all_AGTTC.to_csv('/home/jiayi/5moU/data/DL_fromTombo/all_AGTTC.csv',index=False)
