# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
def perfstat(perfpath):
    perf=pd.read_csv(perfpath)
    auclist=perf['auc']
    describe=perf['auc'].describe()
    return describe

# %%
perfstat('/home/jiayi/5moU/data/DL_fromTombo/all_xgb_perf.csv')
# Out:
# count    54.000000
# mean      0.906838
# std       0.038316
# min       0.839264
# 25%       0.876577
# 50%       0.907546
# 75%       0.936437
# max       0.995595
# Name: auc, dtype: float64

# %%
perfstat('/home/jiayi/5moU/data/DL_fromTombo/avg_xgb_perf.csv')
# Out:
# count    54.000000
# mean      0.625263
# std       0.083534
# min       0.506148
# 25%       0.562383
# 50%       0.614356
# 75%       0.680187
# max       0.866228
# Name: auc, dtype: float64

# %%
perfstat('/home/jiayi/5moU/data/DL_fromTombo/all_RF_perf.csv')
# Out:
# count    54.000000
# mean      0.882107
# std       0.047492
# min       0.755891
# 25%       0.847709
# 50%       0.884298
# 75%       0.923671
# max       0.969915
# Name: auc, dtype: float64

# %%
perfstat('/home/jiayi/5moU/data/DL_fromTombo/avg_RF_perf.csv')
# Out:
# count    54.000000
# mean      0.631692
# std       0.086677
# min       0.507865
# 25%       0.572738
# 50%       0.614956
# 75%       0.681536
# max       0.909540
# Name: auc, dtype: float64

# %%
xgb_all=pd.read_csv('/home/jiayi/5moU/data/DL_fromTombo/all_xgb_perf.csv')
xgb_all
# Out:
#     motif       auc
# 0   ACTAC  0.943363
# 1   ACTGG  0.849926
# 2   ACTTC  0.945299
# 3   AGTAC  0.936649
# 4   AGTTC  0.995595
# 5   CATCA  0.879102
# 6   CATCC  0.911003
# 7   CATCG  0.876301
# 8   CATCT  0.880727
# 9   CATGA  0.884579
# 10  CATGC  0.935345
# 11  CATGG  0.872486
# 12  CATGT  0.963512
# 13  CCTAC  0.899232
# 14  CCTGA  0.869541
# 15  CCTGC  0.941999
# 16  CCTGG  0.921783
# 17  CCTGT  0.946000
# 18  CCTTC  0.839864
# 19  CGTGA  0.873646
# 20  CGTGC  0.850767
# 21  CGTGG  0.850614
# 22  CTTCA  0.946274
# 23  CTTCC  0.915301
# 24  CTTCG  0.920720
# 25  CTTCT  0.897998
# 26  GATCA  0.893714
# 27  GATCC  0.874980
# 28  GATCG  0.904089
# 29  GATCT  0.958248
# 30  GATGA  0.961992
# 31  GATGT  0.938936
# 32  GCTAC  0.935701
# 33  GCTGA  0.886685
# 34  GCTGC  0.873526
# 35  GCTGG  0.839264
# 36  GCTGT  0.877668
# 37  GCTTC  0.960571
# 38  GGTAC  0.971698
# 39  GGTGA  0.872836
# 40  GGTGC  0.877405
# 41  GGTGG  0.868032
# 42  GGTGT  0.879775
# 43  GGTTC  0.935803
# ...

# %%
print(xgb_all.max())
# Out:
# motif       TGTTC
# auc      0.995595
# dtype: object

# %%
print(xgb_all.min())
# Out:
# motif       ACTAC
# auc      0.839264
# dtype: object

# %%
xgb_all['auc'].describe()
# Out:
# count    54.000000
# mean      0.906838
# std       0.038316
# min       0.839264
# 25%       0.876577
# 50%       0.907546
# 75%       0.936437
# max       0.995595
# Name: auc, dtype: float64

# %%
xgb_avg=pd.read_csv('/home/jiayi/5moU/data/DL_fromTombo/avg_xgb_perf.csv')
xgb_avg
# Out:
#     motif       auc
# 0   ACTAC  0.660650
# 1   ACTGG  0.763139
# 2   ACTTC  0.719708
# 3   AGTAC  0.515696
# 4   AGTTC  0.818182
# 5   CATCA  0.650124
# 6   CATCC  0.532211
# 7   CATCG  0.631626
# 8   CATCT  0.548343
# 9   CATGA  0.647421
# 10  CATGC  0.866228
# 11  CATGG  0.757237
# 12  CATGT  0.601871
# 13  CCTAC  0.687217
# 14  CCTGA  0.511496
# 15  CCTGC  0.562296
# 16  CCTGG  0.632719
# 17  CCTGT  0.587272
# 18  CCTTC  0.575640
# 19  CGTGA  0.706670
# 20  CGTGC  0.704296
# 21  CGTGG  0.587409
# 22  CTTCA  0.648185
# 23  CTTCC  0.647235
# 24  CTTCG  0.618058
# 25  CTTCT  0.563114
# 26  GATCA  0.537452
# 27  GATCC  0.506148
# 28  GATCG  0.603270
# 29  GATCT  0.610654
# 30  GATGA  0.727923
# 31  GATGT  0.591325
# 32  GCTAC  0.635025
# 33  GCTGA  0.684255
# 34  GCTGC  0.576305
# 35  GCTGG  0.522909
# 36  GCTGT  0.587874
# 37  GCTTC  0.603246
# 38  GGTAC  0.721488
# 39  GGTGA  0.645072
# 40  GGTGC  0.511657
# 41  GGTGG  0.537967
# 42  GGTGT  0.508424
# 43  GGTTC  0.558834
# ...

# %%
print(xgb_avg.max())
# Out:
# motif       TGTTC
# auc      0.866228
# dtype: object

# %%
xgb_avg['auc'].describe()
# Out:
# count    54.000000
# mean      0.625263
# std       0.083534
# min       0.506148
# 25%       0.562383
# 50%       0.614356
# 75%       0.680187
# max       0.866228
# Name: auc, dtype: float64
