# %%
import pandas as pd
import numpy as np

# %%
data=pd.read_csv('/home/jiayi/5moU/data/DL_fromTombo/all_tombo.csv')
data
# Out:
#          indx   kmer    mean_1    mean_2    mean_3    mean_4    mean_5  \
# 0          20  CATCT -0.261382 -0.290529 -0.375176 -0.548695 -0.420694
# 1          22  TCTTC -0.375176 -0.548695 -0.420694 -0.102165  0.324141
# 2          23  CTTCG -0.548695 -0.420694 -0.102165  0.324141  0.612248
# 3          35  CGTGG -0.134270  0.017096  0.317245  0.286391  0.191036
# 4          44  CCTGC -1.068734 -0.164691  0.164829  0.237456 -0.655237
# ...       ...    ...       ...       ...       ...       ...       ...
# 1822819   350  GCTGG  0.160716  0.201952  0.291149  0.341133  0.261907
# 1822820   365  GATCC  0.713934  0.005522 -0.667390 -0.689873 -0.575091
# 1822821   374  GATCC  0.404221  0.204545 -0.725696 -0.713145  0.062983
# 1822822   377  CCTGA -0.713145  0.062983  0.264506  0.270585  0.073087
# 1822823   380  GATCA  0.270585  0.073087 -0.577806 -0.538803  0.255019
#
#             std_1     std_2     std_3  ...  mdintense_2  mdintense_3  \
# ...

# %%
all_GATGT=data[data['kmer']=="GATGT"]
all_GATGT
# Out:
#          indx   kmer    mean_1    mean_2    mean_3    mean_4    mean_5  \
# 169       792  GATGT  0.695437 -0.469584 -0.244677  0.166784 -0.619996
# 397       252  GATGT  0.512255 -0.305857  0.022603  0.017033 -0.432095
# 987       163  GATGT  0.512871 -0.497382 -0.205308  0.097433 -0.605112
# 1170      454  GATGT  0.382485 -0.432326 -0.132161  0.587094 -0.370832
# 1343      393  GATGT  0.640104 -0.361050 -0.388824 -0.329214 -0.513442
# ...       ...    ...       ...       ...       ...       ...       ...
# 1821148    97  GATGT  0.960401 -0.562450 -0.221959  0.752635 -0.488234
# 1821414   772  GATGT  0.428535 -0.819756 -0.415518  0.242478 -0.799007
# 1821960   792  GATGT  0.642941 -0.779994 -0.432435  0.314762 -0.801372
# 1822421   565  GATGT  0.688542 -0.501493 -0.191662  0.438627 -0.502063
# 1822664   296  GATGT  0.608158 -0.747267 -0.386351  0.383489 -0.751725
#
#             std_1     std_2     std_3  ...  mdintense_2  mdintense_3  \
# ...

# %%
all_GATGT.to_csv('/home/jiayi/5moU/data/DL_fromTombo/all_GATGT.csv',index=False)

# %%
all_GATGA=data[data['kmer']=="GATGA"]
all_GATGA
# Out:
#          indx   kmer    mean_1    mean_2    mean_3    mean_4    mean_5  \
# 69        174  GATGA  0.910491 -0.488466 -0.154817  0.476361  0.603461
# 1588      173  GATGA  0.740966 -0.456914 -0.223984  0.660435  0.498778
# 1818      157  GATGA  0.925567 -0.434805 -0.194485  0.515178  0.496787
# 2131      174  GATGA  0.631904 -0.325172 -0.069864  0.501238  0.534491
# 3059      174  GATGA  0.563095 -0.476060 -0.225073  0.621785  0.353257
# ...       ...    ...       ...       ...       ...       ...       ...
# 1817902   172  GATGA  0.913120 -0.796517 -0.503154  0.552831  0.272477
# 1818312   174  GATGA  1.102270 -0.486977 -0.302162  0.694106  0.374722
# 1820610    75  GATGA  1.025540 -0.578115 -0.344476  0.395096  0.385235
# 1821314   154  GATGA  0.904721 -0.772806 -0.439097  0.489937  0.290091
# 1821860   174  GATGA  0.970743 -0.680621 -0.299677  0.266895  0.291052
#
#             std_1     std_2     std_3  ...  mdintense_2  mdintense_3  \
# ...

# %%
all_GATGA.to_csv('/home/jiayi/5moU/data/DL_fromTombo/all_GATGA.csv',index=False)

# %%
all_TGTGC=data[data['kmer']=="TGTGC"]
all_TGTGC
# Out:
#          indx   kmer    mean_1    mean_2    mean_3    mean_4    mean_5  \
# 78        239  TGTGC -0.393038  0.108138 -0.113532  0.249268 -0.086032
# 221      1169  TGTGC  0.577563  0.486387 -0.108924 -0.400086 -0.315799
# 299       179  TGTGC  0.187476  0.160928 -0.234632  0.034336 -0.355640
# 449       629  TGTGC  0.135409 -0.110499 -0.142222  0.176287 -0.148357
# 561       135  TGTGC -0.328761 -0.313913 -0.315879 -0.368903 -0.261595
# ...       ...    ...       ...       ...       ...       ...       ...
# 1822078    84  TGTGC  0.206723  0.212892 -0.338564 -0.329485 -0.370310
# 1822330    12  TGTGC -0.224099 -0.016030 -0.042468  0.269796 -0.131406
# 1822473   942  TGTGC  0.186421  0.073605 -0.127920  0.148950 -0.254331
# 1822559   262  TGTGC -0.142096 -0.245403 -0.296681 -0.177880 -0.429734
# 1822716   673  TGTGC -0.276376 -0.468163 -0.486387 -0.453849 -0.345809
#
#             std_1     std_2     std_3  ...  mdintense_2  mdintense_3  \
# ...

# %%
all_TGTGC.to_csv('/home/jiayi/5moU/data/DL_fromTombo/all_TGTGC.csv',index=False)

# %%
all_GCTGG=data[data['kmer']=="GCTGG"]
all_GCTGG
# Out:
#          indx   kmer    mean_1    mean_2    mean_3    mean_4    mean_5  \
# 9          89  GCTGG  0.242398 -0.106553  0.511500  0.829785  0.961044
# 24        218  GCTGG  0.763821 -0.280658  0.263080  0.791769  0.798220
# 34         65  GCTGG  0.196160 -0.213190  0.479007  0.863339  0.961940
# 71        186  GCTGG  0.357049 -0.282509  0.323280  0.242086  0.238096
# 86        276  GCTGG -0.057953 -0.305924  0.222037  0.321717 -0.024904
# ...       ...    ...       ...       ...       ...       ...       ...
# 1822755   962  GCTGG  0.392754 -0.300991  0.258568  0.603270  0.775035
# 1822770  1091  GCTGG  0.488268 -0.281154  0.272638  0.644931  0.163869
# 1822791   122  GCTGG  0.344739 -0.355468  0.235667  0.579364  0.862000
# 1822804   221  GCTGG  0.238142 -0.431144  0.302140  0.637440  0.756139
# 1822819   350  GCTGG  0.160716  0.201952  0.291149  0.341133  0.261907
#
#             std_1     std_2     std_3  ...  mdintense_2  mdintense_3  \
# ...

# %%
all_GCTGG.to_csv('/home/jiayi/5moU/data/DL_fromTombo/all_GCTGG.csv',index=False)
