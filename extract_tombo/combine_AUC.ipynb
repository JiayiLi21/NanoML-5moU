# %%
import pandas as pd

# %%
XG_all_perf=pd.read_csv('/home/jiayi/5moU/data/DL_fromTombo/all_xgb_perf.csv')
XG_avg_perf=pd.read_csv('/home/jiayi/5moU/data/DL_fromTombo/avg_xgb_perf.csv')
RF_all_perf=pd.read_csv('/home/jiayi/5moU/data/DL_fromTombo/all_RF_perf.csv')
RF_avg_perf=pd.read_csv('/home/jiayi/5moU/data/DL_fromTombo/avg_RF_perf.csv')
SVM_all_perf=pd.read_csv('/home/jiayi/5moU/data/DL_fromTombo/all_SVM_perf.csv')
SVM_avg_perf=pd.read_csv('/home/jiayi/5moU/data/DL_fromTombo/avg_SVM_perf.csv')

# %%
mid_XG=pd.read_csv('/home/jiayi/5moU/data/DL_fromTombo/mid_xgb_perf.csv')
mid_RF=pd.read_csv('/home/jiayi/5moU/data/DL_fromTombo/mid_RF_perf.csv')
mid_SVM=pd.read_csv('/home/jiayi/5moU/data/DL_fromTombo/mid_SVM_perf.csv')

mid01_XG=pd.read_csv('/home/jiayi/5moU/data/DL_fromTombo/mid01_xgb_perf.csv')
mid01_RF=pd.read_csv('/home/jiayi/5moU/data/DL_fromTombo/mid01_RF_perf.csv')
mid01_SVM=pd.read_csv('/home/jiayi/5moU/data/DL_fromTombo/mid01_SVM_perf.csv')


all_XG=pd.read_csv('/home/jiayi/5moU/data/DL_fromTombo/all_xgb_perf.csv')
all_RF=pd.read_csv('/home/jiayi/5moU/data/DL_fromTombo/all_RF_perf.csv')
all_SVM=pd.read_csv('/home/jiayi/5moU/data/DL_fromTombo/all_SVM_perf.csv')

# %%
AUC=pd.DataFrame()
AUC['motif']=mid_XG['motif']
AUC['mid_XG']=mid_XG['auc']
AUC['mid_RF']=mid_RF['auc']
AUC['mid_SVM']=mid_SVM['auc']
AUC['mid01_XG']=mid01_XG['auc']
AUC['mid01_RF']=mid01_RF['auc']
AUC['mid01_SVM']=mid01_SVM['auc']
AUC['all_XG']=all_XG['auc']
AUC['all_RF']=all_RF['auc']
AUC['all_SVM']=all_SVM['auc']
AUC
AUC.to_csv('/home/jiayi/5moU/data/DL_fromTombo/combine_AUC_9c.csv',index=False)

# %%
AUC=pd.DataFrame()
XG_all_perf
# Out:
#     motif       auc
# 0   ACTAC  0.943363
# 1   ACTGG  0.849926
# 2   ACTTC  0.945299
# 3   AGTAC  0.936649
# 4   AGTTC  0.995595
# 5   CATCA  0.879102
# 6   CATCC  0.911003
# 7   CATCG  0.876301
# 8   CATCT  0.880727
# 9   CATGA  0.884579
# 10  CATGC  0.935345
# 11  CATGG  0.872486
# 12  CATGT  0.963512
# 13  CCTAC  0.899232
# 14  CCTGA  0.869541
# 15  CCTGC  0.941999
# 16  CCTGG  0.921783
# 17  CCTGT  0.946000
# 18  CCTTC  0.839864
# 19  CGTGA  0.873646
# 20  CGTGC  0.850767
# 21  CGTGG  0.850614
# 22  CTTCA  0.946274
# 23  CTTCC  0.915301
# 24  CTTCG  0.920720
# 25  CTTCT  0.897998
# 26  GATCA  0.893714
# 27  GATCC  0.874980
# 28  GATCG  0.904089
# 29  GATCT  0.958248
# 30  GATGA  0.961992
# 31  GATGT  0.938936
# 32  GCTAC  0.935701
# 33  GCTGA  0.886685
# 34  GCTGC  0.873526
# 35  GCTGG  0.839264
# 36  GCTGT  0.877668
# 37  GCTTC  0.960571
# 38  GGTAC  0.971698
# 39  GGTGA  0.872836
# 40  GGTGC  0.877405
# 41  GGTGG  0.868032
# 42  GGTGT  0.879775
# 43  GGTTC  0.935803
# ...

# %%
RF_all_perf
# Out:
#     motif       auc
# 0   ACTAC  0.944566
# 1   ACTGG  0.872004
# 2   ACTTC  0.903694
# 3   AGTAC  0.928336
# 4   AGTTC  0.969915
# 5   CATCA  0.850691
# 6   CATCC  0.877817
# 7   CATCG  0.861330
# 8   CATCT  0.830880
# 9   CATGA  0.848809
# 10  CATGC  0.954959
# 11  CATGG  0.870029
# 12  CATGT  0.920394
# 13  CCTAC  0.933339
# 14  CCTGA  0.827748
# 15  CCTGC  0.930120
# 16  CCTGG  0.899061
# 17  CCTGT  0.889372
# 18  CCTTC  0.839874
# 19  CGTGA  0.841178
# 20  CGTGC  0.817162
# 21  CGTGG  0.826697
# 22  CTTCA  0.926165
# 23  CTTCC  0.896598
# 24  CTTCG  0.908574
# 25  CTTCT  0.878529
# 26  GATCA  0.860308
# 27  GATCC  0.847343
# 28  GATCG  0.864016
# 29  GATCT  0.924764
# 30  GATGA  0.925926
# 31  GATGT  0.934920
# 32  GCTAC  0.909235
# 33  GCTGA  0.837134
# 34  GCTGC  0.856204
# 35  GCTGG  0.793838
# 36  GCTGT  0.879224
# 37  GCTTC  0.927902
# 38  GGTAC  0.968453
# 39  GGTGA  0.811749
# 40  GGTGC  0.842847
# 41  GGTGG  0.803283
# 42  GGTGT  0.832999
# 43  GGTTC  0.944469
# ...

# %%
AUC=pd.DataFrame()
AUC['motif']=XG_all_perf['motif']
AUC['all_XG']=XG_all_perf['auc']
AUC['avg_XG']=XG_avg_perf['auc']
AUC['all_RF']=RF_all_perf['auc']
AUC['avg_RF']=RF_avg_perf['auc']
AUC['all_SVM']=SVM_all_perf['auc']
AUC['avg_SVM']=SVM_avg_perf['auc']
AUC
#AUC.to_csv('/home/jiayi/5moU/data/DL_fromTombo/MLAUC.csv',index=False)
# Out:
#     motif    all_XG    avg_XG    all_RF    avg_RF   all_SVM   avg_SVM
# 0   ACTAC  0.943363  0.660650  0.944566  0.672154  0.950462  0.643632
# 1   ACTGG  0.849926  0.763139  0.872004  0.735721  0.874363  0.713485
# 2   ACTTC  0.945299  0.719708  0.903694  0.684856  0.911206  0.702714
# 3   AGTAC  0.936649  0.515696  0.928336  0.523591  0.942388  0.500000
# 4   AGTTC  0.995595  0.818182  0.969915  0.806034  0.951613  0.776940
# 5   CATCA  0.879102  0.650124  0.850691  0.633285  0.868564  0.534760
# 6   CATCC  0.911003  0.532211  0.877817  0.538150  0.910472  0.502412
# 7   CATCG  0.876301  0.631626  0.861330  0.614112  0.855943  0.572140
# 8   CATCT  0.880727  0.548343  0.830880  0.556619  0.841380  0.500000
# 9   CATGA  0.884579  0.647421  0.848809  0.635489  0.839266  0.606199
# 10  CATGC  0.935345  0.866228  0.954959  0.909540  0.852906  0.870690
# 11  CATGG  0.872486  0.757237  0.870029  0.796627  0.909220  0.718467
# ...
