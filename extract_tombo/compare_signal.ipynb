# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
all_tombo=pd.read_csv('/home/jiayi/5moU/data/DL_fromTombo/all_tombo.csv')
all_tombo
# Out:
#          indx   kmer    mean_1    mean_2    mean_3    mean_4    mean_5  \
# 0          20  CATCT -0.261382 -0.290529 -0.375176 -0.548695 -0.420694
# 1          22  TCTTC -0.375176 -0.548695 -0.420694 -0.102165  0.324141
# 2          23  CTTCG -0.548695 -0.420694 -0.102165  0.324141  0.612248
# 3          35  CGTGG -0.134270  0.017096  0.317245  0.286391  0.191036
# 4          44  CCTGC -1.068734 -0.164691  0.164829  0.237456 -0.655237
# ...       ...    ...       ...       ...       ...       ...       ...
# 1822819   350  GCTGG  0.160716  0.201952  0.291149  0.341133  0.261907
# 1822820   365  GATCC  0.713934  0.005522 -0.667390 -0.689873 -0.575091
# 1822821   374  GATCC  0.404221  0.204545 -0.725696 -0.713145  0.062983
# 1822822   377  CCTGA -0.713145  0.062983  0.264506  0.270585  0.073087
# 1822823   380  GATCA  0.270585  0.073087 -0.577806 -0.538803  0.255019
#
#             std_1     std_2     std_3  ...  mdintense_2  mdintense_3  \
# ...

# %%
SM=pd.DataFrame()
SM['indx']=all_tombo['indx']
SM['kmer']=all_tombo['kmer']
SM['mean_middle']=all_tombo['mean_3']
SM['std_middle']=all_tombo['std_3']
SM['mdintense_middle']=all_tombo['mdintense_3']
SM['length2_middle']=all_tombo['L-3']
SM['label']=all_tombo['label']
SM
# Out:
#          indx   kmer  mean_middle  std_middle  mdintense_middle  \
# 0          20  CATCT    -0.375176    0.075762         -0.405521
# 1          22  TCTTC    -0.420694    0.065934         -0.413797
# 2          23  CTTCG    -0.102165    0.077537         -0.103449
# 3          35  CGTGG     0.317245    0.178935          0.318624
# 4          44  CCTGC     0.164829    0.052036          0.161381
# ...       ...    ...          ...         ...               ...
# 1822819   350  GCTGG     0.291149    0.118291          0.291096
# 1822820   365  GATCC    -0.667390    0.056848         -0.688690
# 1822821   374  GATCC    -0.725696    0.098837         -0.731289
# 1822822   377  CCTGA     0.264506    0.070813          0.243763
# 1822823   380  GATCA    -0.577806    0.213394         -0.627157
#
#          length2_middle  label
# 0                    12      1
# 1                     6      1
# 2                    29      1
# 3                     6      1
# 4                    18      1
# ...

# %%
SM.to_csv('/home/jiayi/5moU/data/DL_fromTombo/mid_tombo.csv',index=False)

# %%
sns.displot(SM, x="mean_middle", hue="label", stat="density", common_norm=False)

# %%
sns.displot(SM, x="std_middle", hue="label", stat="density", common_norm=False)

# %%
sns.displot(SM, x="mdintense_middle", hue="label", stat="density", common_norm=False)

# %%
sns.displot(SM, x="length2_middle", hue="label", stat="density", common_norm=False)
